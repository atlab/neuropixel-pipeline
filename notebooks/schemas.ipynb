# %%
# %load_ext autoreload

# %autoreload 2

import datajoint as dj

from neuropixel_pipeline.schemata import base, probe, ephys

dj.Diagram(base) + dj.Diagram(probe) + dj.Diagram(ephys)

# %%
# %pip install "pydantic>=2.0a4"
# Out:
# ...
#   Using cached pydantic-2.0a4-py3-none-any.whl (197 kB)
# ...
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.4 MB 1.5 MB/s eta 0:00:01
#      -------------------- ------------------- 0.7/1.4 MB 7.5 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 10.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 0.23.1
#     Uninstalling pydantic_core-0.23.1:
#       Successfully uninstalled pydantic_core-0.23.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\cpapa\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python38\\site-packages\\~ydantic_core\\_pydantic_core.cp38-win_amd64.pyd'
# ...

# %%
dj.Diagram(base)

# %%
dj.Diagram(probe)

# %%
dj.Diagram(ephys)
